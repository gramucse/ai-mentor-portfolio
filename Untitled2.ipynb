# %% [markdown]
# <a href="https://colab.research.google.com/github/gramucse/ai-mentor-portfolio/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid, proposed by Andrew Ng (DeepLearning.AI), outlines the hierarchical and interdependent skills needed for successful AI projects:
#
# *   **Foundation (Data & Infrastructure):** Encompasses skills in data collection, cleaning, labeling, and managing the underlying computational infrastructure.
# *   **Model Building & Training:** Focuses on developing, training, and optimizing machine learning models using various algorithms and frameworks.
# *   **Deployment & Integration:** Covers the skills required to take trained models and deploy them into production, integrating them into existing systems and applications.
# *   **Monitoring & Maintenance:** Involves continuously monitoring deployed models for performance degradation, bias, and drift, then updating or retraining them as needed.
# *   **Strategy & Ethics (Apex):** At the top, this layer emphasizes understanding business value, strategic planning for AI, and ensuring ethical, fair, and responsible AI implementation.
