# %% [markdown]
# <a href="https://colab.research.google.com/github/gramucse/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash-lite',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# Here's the 5-Layer AI Skill Pyramid in 4 short bullet points:
#
# *   **Foundation (Data):** Understanding and manipulating data (collection, cleaning, preprocessing) is the base.
# *   **Building Blocks (Algorithms & Models):** Proficiency in AI algorithms, machine learning models, and statistical concepts forms the next level.
# *   **Engineering (Development & Deployment):** Skills in AI development, MLOps, and deploying models into production are crucial.
# *   **Application & Strategy (Problem Solving & Ethics):** The apex involves applying AI to solve real-world problems, understanding ethical implications, and strategic thinking.
